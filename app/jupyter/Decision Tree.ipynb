# %% [markdown]
# # Decision Tree

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# details - https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=24)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
print(clf.score(X_train, y_train))

# Can we guess what would this scores be?
# Out:
# 0.9736842105263158
# 0.9827586206896551

# %% [markdown]
# ### Messing with train data

# %%
import numpy as np

X_train = np.append(X_train, [X_train[0]], axis=0)
y_train = np.append(y_train, [not y_train[0]], axis=0)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
print(clf.score(X_train, y_train))

# what would the scores be now?
# Out:
# 0.9473684210526315
# 0.9829059829059829

# %%
import random

for _ in range(3):
    X_train = np.append(X_train, [X_train[0]], axis=0)
    y_train = np.append(y_train, random.sample([0,1,2], 1), axis=0)

# %%
clf = DecisionTreeClassifier(class_weight={0:78, 1:67, 2:56})
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
print(clf.score(X_train, y_train))
# Out:
# 0.9473684210526315
# 0.975

# %% [markdown]
# # Visualizing DT

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plot_tree(clf, filled=True)
plt.show()

# %%
# Any ideas how to make tree not grow fully and avoid overfitting?

# %%
# todo: keep the tree as a dict like this
# returns: {"feature": 3, "threshold": 2.5, "true": {"feature: , "threshold": ,}, "false":} (if there has been a place to cut & when we want to create the tree up to the end) try adding max depth & so on
# or
# None if there was no more place


# much better if we do it this way, don't make dicts, make 2 dicts as node and leaf if there should be returned a number, return a node type object which has node.left, node.right, by default .left/.right = None, continue as long as no node is created if all of them are leafs
# leaf(node) has a number of which class it came and the probability of that class (second one is optional)

# without maxdepth do as long as it can go deeper

# %%
class DecisionTree:
    def __init__(self):
        pass
    
    def fit(self, X, y):
        # creates the dictionary/tree
        pass
    
    def predict(self, X):
        # should go over tree, go over true/false, returns numbers as predictions
        pass
                                
    def gini(self, y1, y2):
        # y1 - is of left one
        # y2 - is of the right one
        # should retur
        pass

# %% [markdown]
# # Homework

# %% [markdown]
# 1. create a decision_tree.py file;
# 2. this python file should receive as an argument data full path (--data_path) target column name (--target) and 3 possible argument values (max_depth, criterion, max_leaf_nodes and random_state). First two should be neccessary arguments, the other 3, if not given, should get some default values set by you;
# 3. https://docs.python.org/3/howto/argparse.html - a tutorial how to add arguments to a python file run;
# 4. the file should read arguments, read dataset, separate X and y according to target column name, handle categorical columns (you can drop them, this task is not about it) and build a decision tree model by given (if not given, default) params of max_depth, class_weight and max_leaf_nodes;
# 5. You don't need to do CV here or tune parameters. You need to just fit the model on whole data;
# 6. The code should save built tree in the same directory as the decision_tree.py file is by name tree.png;
# 7. Besides that, you need to build this tree for classification.csv dataset with your default parameters, save that image as example.png and sent it alongside your code;
# 8. Our TA will run the following code first
#
#
# python decision_tree.py --data_path <path_to_classification.csv>  --target default
#
#
# 9. If everything is correct, the output png file should be the same as the one you sent. This would be the initial check of correctnes for your code.

# %%
#TODO v
# python main.py --name Sona
# send the image to the TA as well
# take into account that the line running it shouldn't be only for classification.csv, also be coutious of non-numerical data, check get dummies handler of test
